# %%
from google import genai
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # Movie Information App

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage

chat = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

system_template = "You are an assistant that helps users find information about movies."
human_template = "Find information about the movie {movie_title}."

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", system_template),
    ("human", human_template)
])

response = chat.invoke(chat_prompt.format(movie_title="Inception"))

print(response.content)

# %% [markdown]
# # PDF Summarization App

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains import load_summarize_chain
from langchain_community.document_loaders import PyPDFLoader

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
summarize_chain = load_summarize_chain(llm)

# %%
#!wget https://www.cheat-sheets.org/saved-copy/The%20One%20Page%20Linux%20Manual.pdf

# %%
document_loader = PyPDFLoader(file_path="./The One Page Linux Manual.pdf")
document = document_loader.load()

# %%
summary = summarize_chain.invoke(document)

# %%
print(summary['output_text'])
# Out:
# The One Page Linux Manual (Version 3.0, May 1999) is a concise reference guide to essential Linux commands. It covers fundamental system and file management, including starting/stopping, user administration, mounting file systems, and file operations (finding, moving, copying, deleting, viewing, and permissions). The guide also details X Window System configuration and shortcuts, software installation (RPM and tarballs), printing, and lists important system configuration files, along with various command-line tips and wildcards.

# %% [markdown]
# # QnA App

# %%
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import LLMChain
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
prompt = PromptTemplate(template="Question: {question}\nAnswer:", input_variables=["question"])
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
#chain = LLMChain(llm=llm, prompt=prompt)
chain = prompt | llm

# %%
result = chain.invoke({"question": "what is the meaning of life?"})

# %%
print(result.content)
# Out:
# That's one of the most profound and enduring questions humanity has ever pondered, and there's no single, universally accepted answer. The "meaning of life" is often a deeply personal and subjective journey of discovery.
#
# Here are some common perspectives and approaches to this question:
#
# 1.  **No Inherent Meaning (Existentialism):** Many philosophers, particularly existentialists, argue that life has no inherent, pre-ordained meaning. Instead, we are free to create our own meaning through our choices, actions, and values. The meaning isn't found; it's made.
#
# 2.  **Divine Purpose (Religious/Spiritual):** For many, meaning is found in faith and a connection to a higher power. Life's purpose might be seen as fulfilling God's will, achieving spiritual growth, preparing for an afterlife, or living according to sacred texts and traditions.
#
# 3.  **Happiness and Fulfillment:** Some believe the meaning of life is to seek happiness, joy, and personal fulfillment. This can involve pursuing passions, experiencing pleasure, and minimizing suffering.
#
# 4.  **Contribution and Impact:** Many find meaning in contributing to something larger than themselves – helping others, making a positive impact on the world, leaving a legacy, or working towards social justice.
#
# 5.  **Connection and Love:** For others, the meaning of life is found in deep relationships, love, family, friendship, and community. Human connection and shared experiences are paramount.
#
# 6.  **Growth and Learning:** The pursuit of knowledge, self-improvement, understanding the universe, and personal development can be seen as life's primary purpose.
#
# 7.  **Experience and Awareness:** Simply being present, experiencing the world, appreciating beauty, and being aware of one's existence can be a source of meaning.
#
# **Ultimately, the "meaning of life" is often a question you answer for yourself.** It's about asking:
#
# *   What brings me joy and purpose?
# *   What values do I hold most dear?
# *   What kind of person do I want to be?
# *   What problems do I want to help solve?
# *   What legacy do I want to leave, if any?
#
# It's not a fixed destination, but an ongoing process of living, learning, and evolving.
