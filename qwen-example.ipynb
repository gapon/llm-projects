# %%
from openai import OpenAI

client = OpenAI(
    base_url='https://llm.citydrive.tech/api',
    api_key='sk-9441b260eccc466d877734c7c52c0897',
)

response = client.chat.completions.create(
    model='qwen3-coder:30b',
    messages=[
        {"role": "system", "content": "Ты промпт-инженер"},
        {"role": "user", "content": "Составь шаблон промпта, используя цепочку размышлений"}
    ]
)
print(response.choices[0].message.content)
# Out:
# Конечно! Ниже приведён **шаблон промпта с использованием цепочки размышлений (Chain-of-Thought, CoT)**. Такой шаблон подходит для задач, где требуется не только дать ответ, но и объяснить процесс мышления, чтобы модель могла лучше понять логику решения.
#
# ---
#
# ### 🧠 Шаблон промпта с цепочкой размышлений (Chain-of-Thought)
#
# > "Размышляй шаг за шагом. Проанализируй задачу и опиши свой путь мысли, прежде чем давать ответ.
# >
# > Задача: [Вставь здесь конкретную задачу или вопрос]
# >
# > Шаг 1: [Опиши, что ты понимаешь из условия задачи]
# > Шаг 2: [Определи, какие данные или принципы применимы]
# > Шаг 3: [Продумай логику решения, шаг за шагом]
# > Шаг 4: [Сделай вывод или вычисли результат]
# >
# > Ответ: [Кратко и чётко укажи финальный ответ]"
#
# ---
#
# ### Пример использования:
#
# > "Размышляй шаг за шагом. Проанализируй задачу и опиши свой путь мысли, прежде чем давать ответ.
# >
# > Задача: В коробке 12 шариков, 5 из них красные, 4 — синие, остальные — зелёные. Какова вероятность вытащить один зелёный шар?
# >
# > Шаг 1: Всего шариков — 12. Из них красных 5, синих 4, остальные — зелёные.
# > Шаг 2: Чтобы найти количество зелёных шариков, вычтем красные и синие из общего числа: 12 - 5 - 4 = 3.
# > Шаг 3: Вероятность вытащить один зелёный шар — это отношение числа зелёных шариков к общему числу шариков: 3/12 = 1/4.
# > Шаг 4: Итак, вероятность вытащить один зелёный шар равна 1/4 или 0.25.
# >
# > Ответ: 0.25"
#
# ---
#
# Если нужно, я могу адаптировать шаблон под конкретную область (математика, логика, анализ текста и т.д.).

# %%
def test():
    response = client.chat.completions.create(
        model='qwen3-coder:30b',
        messages=[
            {"role": "system", "content": "Ты промпт-инженер"},
            {"role": "user", "content": "Составь шаблон промпта, используя цепочку размышлений"}
        ]
    )

# %%
# %timeit test()
# Out:
# 8.38 s ± 1.22 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
